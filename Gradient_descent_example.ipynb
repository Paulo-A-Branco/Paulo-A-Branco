# %% [markdown]
# <a href="https://colab.research.google.com/github/Paulo-A-Branco/Paulo-A-Branco/blob/main/Gradient_descent_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
# y = x2
x = np.arange(-10,10, 0.1)

# %%
y = x**2

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x,y)

# %%
import random
a1 = random.randint(-10,10)
lr = 0.1

# %%
a2 = a1 - lr * 2*a1
a3 = a2 -lr *2*a2
a4 = a3 -lr * 2*a3

# %%
values = [a1]
derivada = 10
i = 0
while derivada > 0.0001:
  print("i value is ", i)
  next_value = values[i] - lr * 2*values[i]
  print(next_value)
  values.append(next_value)
  print(values)
  derivada = abs(2*values[i])
  print(derivada)

  i = i +1
# Out:
# i value is  0
# -4.8
# [-6, -4.8]
# 12
# i value is  1
# -3.84
# [-6, -4.8, -3.84]
# 9.6
# i value is  2
# -3.072
# [-6, -4.8, -3.84, -3.072]
# 7.68
# i value is  3
# -2.4576000000000002
# [-6, -4.8, -3.84, -3.072, -2.4576000000000002]
# 6.144
# i value is  4
# -1.9660800000000003
# [-6, -4.8, -3.84, -3.072, -2.4576000000000002, -1.9660800000000003]
# 4.9152000000000005
# i value is  5
# -1.5728640000000003
# [-6, -4.8, -3.84, -3.072, -2.4576000000000002, -1.9660800000000003, -1.5728640000000003]
# 3.9321600000000005
# i value is  6
# -1.2582912000000002
# [-6, -4.8, -3.84, -3.072, -2.4576000000000002, -1.9660800000000003, -1.5728640000000003, -1.2582912000000002]
# 3.1457280000000005
# i value is  7
# -1.0066329600000001
# [-6, -4.8, -3.84, -3.072, -2.4576000000000002, -1.9660800000000003, -1.5728640000000003, -1.2582912000000002, -1.0066329600000001]
# 2.5165824000000003
# i value is  8
# -0.8053063680000001
# ...

# %%
import time
lr = 0.7
iter = 20
values = [a1]
for _ in range(iter):
  plt.plot(x,y)
  plt.scatter(values, np.array(values)**2, cmap=x)
  values.append(values[-1] - lr*2*values[-1]) 
  plt.show()
  time.sleep(1)
